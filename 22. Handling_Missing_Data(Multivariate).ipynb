# %% [markdown]
# # Multivariate Handling of Missing Data
#
# `Multivariate missing data` handling techniques use information from **multiple features simultaneously**
# to estimate missing values. These methods are more powerful than univariate approaches because they
# leverage relationships between variables.
#
# They are especially useful when features are correlated and missingness depends on other variables.
#
# ---
#
# ## KNN Imputer
#
# The **KNN Imputer** fills missing values by finding the **K nearest samples** (based on feature similarity)
# and imputing missing values using their average or majority value.
#
# ### Key Characteristics
#
# - Uses similarity between samples
# - Considers relationships across multiple features
# - Non-parametric and data-driven
#
# ### When to Use
#
# - Features are correlated
# - Dataset size is small to medium
# - Missingness is not completely random
#
# ### Works Well With
#
# - k-Nearest Neighbors
# - Tree-based models
# - Distance-sensitive algorithms
#
# ---
#
# ## Iterative Imputer
#
# The **Iterative Imputer** models each feature with missing values as a function of other features
# using a regression-based approach. Missing values are predicted iteratively until convergence.
#
# ### Key Characteristics
#
# - Captures complex multivariate relationships
# - Supports different underlying estimators
# - More flexible than KNN-based imputation
#
# ### When to Use
#
# - Strong dependencies exist between features
# - Dataset size is moderate
# - Higher imputation accuracy is required
#
# ### Works Well With
#
# - Linear and logistic regression
# - Tree-based models
# - Ensemble algorithms
#
# ---
#
# ## Comparison of Multivariate Imputation Methods
#
# | Method | Uses Feature Relationships | Computational Cost | Best For |
# |------|----------------------------|--------------------|----------|
# | KNN Imputer | Yes | Medium | Correlated features, smaller datasets |
# | Iterative Imputer | Yes | High | Complex dependencies, higher accuracy |
#
# ---
#
# ## Best Practices
#
# - Scale features before applying KNN Imputer
# - Avoid multivariate imputers on very large datasets
# - Always fit imputers on training data only
# - Use pipelines to prevent data leakage
#
# ---
#
# ## Summary
#
# Multivariate imputation techniques provide more accurate missing value estimates by leveraging
# relationships between features. KNN Imputer is simple and effective for correlated data, while
# Iterative Imputer is more powerful for capturing complex dependencies, making both valuable tools
# in advanced machine learning preprocessing workflows.

# %%
# %%capture
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn

# %% [markdown]
# ### **KNN Imputer**

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

from sklearn.impute import KNNImputer,SimpleImputer
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('Titanic.csv')[['Age','Pclass','Fare','Survived']]
df.head()
# Out:
#     Age  Pclass     Fare  Survived
# 0  22.0       3   7.2500         0
# 1  38.0       1  71.2833         1
# 2  26.0       3   7.9250         1
# 3  35.0       1  53.1000         1
# 4  35.0       3   8.0500         0

# %%
df.isnull().mean() * 100
# Out:
# Age         19.86532
# Pclass       0.00000
# Fare         0.00000
# Survived     0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)
X_train.head()
# Out:
#       Age  Pclass     Fare
# 30   40.0       1  27.7208
# 10    4.0       3  16.7000
# 873  47.0       3   9.0000
# 182   9.0       3  31.3875
# 876  20.0       3   9.8458

# %%
knn = KNNImputer(n_neighbors=3,weights='distance')

X_train_trf = knn.fit_transform(X_train)
X_test_trf = knn.transform(X_test)

# %%
lr = LogisticRegression()

lr.fit(X_train_trf,y_train)

y_pred = lr.predict(X_test_trf)

accuracy_score(y_test,y_pred)
# Out:
# 0.7039106145251397

# %%
# Comparision with Simple Imputer --> mean

si = SimpleImputer()

X_train_trf2 = si.fit_transform(X_train)
X_test_trf2 = si.transform(X_test)

# %%
lr = LogisticRegression()

lr.fit(X_train_trf2,y_train)

y_pred2 = lr.predict(X_test_trf2)

accuracy_score(y_test,y_pred2)
# Out:
# 0.6927374301675978

# %% [markdown]
# ### **Iterative Imputer(From Scratch)**

# %%
df = np.round(pd.read_csv('Startups.csv')[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)
np.random.seed(9)
df = df.sample(5)
df
# Out:
#     R&D Spend  Administration  Marketing Spend  Profit
# 21        8.0            15.0             30.0    11.0
# 37        4.0             5.0             20.0     9.0
# 2        15.0            10.0             41.0    19.0
# 14       12.0            16.0             26.0    13.0
# 44        2.0            15.0              3.0     7.0

# %%
df = df.iloc[:,0:-1]
df
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0            15.0             30.0
# 37        4.0             5.0             20.0
# 2        15.0            10.0             41.0
# 14       12.0            16.0             26.0
# 44        2.0            15.0              3.0

# %%
df.iloc[1,0] = np.nan
df.iloc[3,1] = np.nan
df.iloc[-1,-1] = np.nan
df.head()
# Out:
# C:\Users\Msi Laptop\AppData\Local\Temp\ipykernel_13172\1429726703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[1,0] = np.nan
# C:\Users\Msi Laptop\AppData\Local\Temp\ipykernel_13172\1429726703.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.iloc[3,1] = np.nan
# C:\Users\Msi Laptop\AppData\Local\Temp\ipykernel_13172\1429726703.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
# Step 1 - Impute all missing values with mean of respective col

df0 = pd.DataFrame()

df0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

# %%
# 0th Iteration
df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37       9.25            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            29.25

# %%
# Remove the col1 imputed value
df1 = df0.copy()

df1.iloc[1,0] = np.nan

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.25            26.00
# 44        2.0           15.00            29.25

# %%
# Use first 3 rows to build a model and use the last for prediction

X = df1.iloc[[0,2,3,4],1:3]
X
# Out:
#     Administration  Marketing Spend
# 21           15.00            30.00
# 2            10.00            41.00
# 14           11.25            26.00
# 44           15.00            29.25

# %%
y = df1.iloc[[0,2,3,4],0]
y
# Out:
# 21     8.0
# 2     15.0
# 14    12.0
# 44     2.0
# Name: R&D Spend, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23.14158651])

# %%
df1.iloc[1,0] = 23.14
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.25            26.00
# 44       2.00           15.00            29.25

# %%
# Remove the col2 imputed value

df1.iloc[3,1] = np.nan

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00            15.0            30.00
# 37      23.14             5.0            20.00
# 2       15.00            10.0            41.00
# 14      12.00             NaN            26.00
# 44       2.00            15.0            29.25

# %%
# Use last 3 rows to build a model and use the first for prediction
X = df1.iloc[[0,1,2,4],[0,2]]
X
# Out:
#     R&D Spend  Marketing Spend
# 21       8.00            30.00
# 37      23.14            20.00
# 2       15.00            41.00
# 44       2.00            29.25

# %%
y = df1.iloc[[0,1,2,4],1]
y
# Out:
# 21    15.0
# 37     5.0
# 2     10.0
# 44    15.0
# Name: Administration, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.06331285])

# %%
df1.iloc[3,1] = 11.06
df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.06            26.00
# 44       2.00           15.00            29.25

# %%
# Remove the col3 imputed value
df1.iloc[4,-1] = np.nan

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00             30.0
# 37      23.14            5.00             20.0
# 2       15.00           10.00             41.0
# 14      12.00           11.06             26.0
# 44       2.00           15.00              NaN

# %%
# Use last 3 rows to build a model and use the first for prediction
X = df1.iloc[0:4,0:2]
X
# Out:
#     R&D Spend  Administration
# 21       8.00           15.00
# 37      23.14            5.00
# 2       15.00           10.00
# 14      12.00           11.06

# %%
y = df1.iloc[0:4,-1]
y
# Out:
# 21    30.0
# 37    20.0
# 2     41.0
# 14    26.0
# Name: Marketing Spend, dtype: float64

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.predict(df1.iloc[4,0:2].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([31.56351448])

# %%
df1.iloc[4,-1] = 31.56
# After 1st Iteration

df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.14            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.06            26.00
# 44       2.00           15.00            31.56

# %%
# Subtract 0th iteration from 1st iteration

df1 - df0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00             0.00
# 37      13.89            0.00             0.00
# 2        0.00            0.00             0.00
# 14       0.00           -0.19             0.00
# 44       0.00            0.00             2.31

# %%
df2 = df1.copy()

df2.iloc[1,0] = np.nan

df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.06            26.00
# 44        2.0           15.00            31.56

# %%
X = df2.iloc[[0,2,3,4],1:3]
y = df2.iloc[[0,2,3,4],0]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[1,1:].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([23.78627207])

# %%
df2.iloc[1,0] = 23.78

# %%
df2.iloc[3,1] = np.nan
X = df2.iloc[[0,1,2,4],[0,2]]
y = df2.iloc[[0,1,2,4],1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.22020174])

# %%
df2.iloc[3,1] = 11.22

# %%
df2.iloc[4,-1] = np.nan

X = df2.iloc[0:4,0:2]
y = df2.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[4,0:2].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38.87979054])

# %%
df2.iloc[4,-1] = 31.56
df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      23.78            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.22            26.00
# 44       2.00           15.00            31.56

# %%
df2 - df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00              0.0
# 37       0.64            0.00              0.0
# 2        0.00            0.00              0.0
# 14       0.00            0.16              0.0
# 44       0.00            0.00              0.0

# %%
df3 = df2.copy()

df3.iloc[1,0] = np.nan

df3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21        8.0           15.00            30.00
# 37        NaN            5.00            20.00
# 2        15.0           10.00            41.00
# 14       12.0           11.22            26.00
# 44        2.0           15.00            31.56

# %%
X = df3.iloc[[0,2,3,4],1:3]
y = df3.iloc[[0,2,3,4],0]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[1,1:].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([24.57698058])

# %%
df3.iloc[1,0] = 24.57

# %%
df3.iloc[3,1] = np.nan
X = df3.iloc[[0,1,2,4],[0,2]]
y = df3.iloc[[0,1,2,4],1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11.37282844])

# %%
df3.iloc[3,1] = 11.37

# %%
df3.iloc[4,-1] = np.nan

X = df3.iloc[0:4,0:2]
y = df3.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df3.iloc[4,0:2].values.reshape(1,2))
# Out:
# C:\Users\Msi Laptop\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([45.53976417])

# %%
df3.iloc[4,-1] = 45.53
df2.iloc[3,1] = 11.22
df3
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       8.00           15.00            30.00
# 37      24.57            5.00            20.00
# 2       15.00           10.00            41.00
# 14      12.00           11.37            26.00
# 44       2.00           15.00            45.53

# %%
df3 - df2
# Out:
#     R&D Spend  Administration  Marketing Spend
# 21       0.00            0.00             0.00
# 37       0.79            0.00             0.00
# 2        0.00            0.00             0.00
# 14       0.00            0.15             0.00
# 44       0.00            0.00            13.97
