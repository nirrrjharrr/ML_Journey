# %% [markdown]
# ## K-Nearest Neighbors (KNN)
#
# `K-Nearest Neighbors (KNN)` is a **supervised, non-parametric algorithm** used for
# both **classification** and **regression**.
# It makes predictions based on the **K closest data points** in the feature space.
#
# KNN is intuitive and relies on the idea:
# > **Similar data points have similar outputs**
#
# ---
#
# ### Why KNN Is Needed
#
# Some problems:
# - Do not follow a simple linear pattern
# - Require flexible decision boundaries
# - Benefit from instance-based learning
#
# KNN helps by:
# - Making no assumptions about data distribution
# - Adapting naturally to complex patterns
# - Using data directly instead of learning parameters
#
# ---
#
# ### Core Idea of KNN
#
# KNN works by:
# - Measuring distance between a test point and all training points
# - Selecting the **K nearest neighbors**
# - Aggregating their outputs to make a prediction
#
# There is **no explicit training phase**.
#
# ---
#
# ### How KNN Works
#
# 1. Choose the value of \( K \)
# 2. Compute distance between test point and all training points
# 3. Select the \( K \) closest neighbors
# 4. Aggregate their outputs
# 5. Return the final prediction
#
# ---
#
# ### KNN for Classification
#
# - Each neighbor votes for a class
# - Final class is decided by **majority voting**
#
# ---
#
# ### KNN for Regression
#
# - Each neighbor contributes a numerical value
# - Final prediction is the **average of neighbors’ values**
#
# $$
# \hat{y}_{final} = \frac{1}{K} \sum_{i=1}^{K} y_i
# $$
#
# ---
#
# ### Distance Metrics
#
# Distance defines “closeness” in KNN.
#
# Common metrics:
# - Euclidean
# - Manhattan
# - Minkowski
# - Cosine (for high-dimensional data)
#
# Choice of distance strongly affects performance.
#
# ---
#
# ### Importance of Feature Scaling
#
# - KNN is **distance-based**
# - Features with larger scales dominate distance
# - Standardization or normalization is essential
#
# Without scaling, KNN gives misleading results.
#
# ---
#
# ### Choosing the Value of K
#
# - Small \( K \) → low bias, high variance (overfitting)
# - Large \( K \) → high bias, low variance (underfitting)
#
# Best practice:
# - Use cross-validation
# - Try odd values of \( K \) for classification
#
# ---
#
# ### Bias–Variance Perspective
#
# | K Value | Bias | Variance |
# |------|------|----------|
# | Small K | Low | High |
# | Large K | High | Low |
#
# ---
#
# ### Advantages of KNN
#
# - Simple and intuitive
# - No training phase
# - Captures non-linear decision boundaries
# - Effective with small datasets
#
# ---
#
# ### Limitations of KNN
#
# - Computationally expensive at prediction time
# - Requires storing entire dataset
# - Sensitive to noise and outliers
# - Performs poorly in high dimensions (curse of dimensionality)
#
# ---
#
# ### KNN vs Other Algorithms
#
# | Aspect | KNN | Linear Models | Tree Models |
# |------|----|---------------|------------|
# | Training | None | Required | Required |
# | Non-linearity | Yes | No | Yes |
# | Scalability | Poor | Good | Good |
# | Interpretability | Medium | High | Medium |
#
# ---
#
# ### When to Use KNN
#
# Use KNN when:
# - Dataset is small to medium
# - Decision boundary is complex
# - Data is well-scaled
#
# Avoid when:
# - Dataset is very large
# - Feature dimensionality is high
# - Real-time prediction is required
#
# ---
#
# ### Practical Notes
#
# - Always scale features before applying KNN
# - Use KD-tree or Ball-tree for faster search
# - Tune \( K \) using cross-validation
#
# ---
#
# ### Key Takeaways
#
# - KNN is an instance-based, distance-driven algorithm
# - Performance depends heavily on distance metric and scaling
# - Simple but computationally expensive
# - Suffers from curse of dimensionality
#
# KNN is an excellent algorithm for building intuition about
# distance-based learning and non-parametric models.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../../Breast_cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop(columns=['id','Unnamed: 32'],inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,1:], df.iloc[:,0],test_size=0.2, random_state=2)
X_train.head()
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 560        14.05         27.15           91.38      600.4          0.09929
# 428        11.13         16.62           70.47      381.1          0.08151
# 198        19.18         22.49          127.50     1148.0          0.08523
# 203        13.81         23.75           91.56      597.8          0.13230
# 41         10.95         21.35           71.90      371.1          0.12270
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 560           0.11260         0.04462              0.04304         0.1537
# 428           0.03834         0.01369              0.01370         0.1511
# 198           0.14280         0.11140              0.06772         0.1767
# 203           0.17680         0.15580              0.09176         0.2251
# 41            0.12180         0.10440              0.05669         0.1895
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# ...

# %%
X_train.shape
# Out:
# (455, 30)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.01330339,  1.7757658 , -0.01491962, ..., -0.13236958,
#         -1.08014517, -0.03527943],
#        [-0.8448276 , -0.6284278 , -0.87702746, ..., -1.11552632,
#         -0.85773964, -0.72098905],
#        [ 1.44755936,  0.71180168,  1.47428816, ...,  0.87583964,
#          0.4967602 ,  0.46321706],
#        ...,
#        [-0.46608541, -1.49375484, -0.53234924, ..., -1.32388956,
#         -1.02997851, -0.75145272],
#        [-0.50025764, -1.62161319, -0.527814  , ..., -0.0987626 ,
#          0.35796577, -0.43906159],
#        [ 0.96060511,  1.21181916,  1.00427242, ...,  0.8956983 ,
#         -1.23064515,  0.50697397]], shape=(455, 30))

# %%
X_train.shape
# Out:
# (455, 30)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
from sklearn.metrics import accuracy_score

y_pred = knn.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.9912280701754386

# %%
scores = []

for i in range(1,16):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    
    knn.fit(X_train,y_train)
    
    y_pred = knn.predict(X_test)

    scores.append(accuracy_score(y_test, y_pred))

# %%
import matplotlib.pyplot as plt

plt.plot(range(1,16),scores)

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets
from sklearn.preprocessing import StandardScaler
from ipywidgets import interact, fixed

def load_data():
    cancer = datasets.load_breast_cancer()
    return cancer

def plot_decision_boundaries(n_neighbors, data, labels):
    h = .02
    cmap_light = ListedColormap(['orange', 'blue'])
    cmap_bold = ListedColormap(['darkorange', 'darkblue'])

    clf = neighbors.KNeighborsClassifier(n_neighbors)
    clf.fit(data, labels)

    x_min, x_max = data[:, 0].min() - 1, data[:, 0].max() + 1
    y_min, y_max = data[:, 1].min() - 1, data[:, 1].max() + 1

    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

    Z = Z.reshape(xx.shape)
    #plt.figure(figsize=(8, 6))
    plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

    plt.scatter(data[:, 0], data[:, 1], c=labels, cmap=cmap_bold, edgecolor='k', s=20)
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    plt.title(f'2-Class classification (k = {n_neighbors})')
    plt.show()

cancer = load_data()

# Use only the first two features and standardize them.
X = StandardScaler().fit_transform(cancer.data[:, :2])
y = cancer.target

# Interactive widget
interact(plot_decision_boundaries, n_neighbors=(1, 20), data=fixed(X), labels=fixed(y));
# Out:
# interactive(children=(IntSlider(value=10, description='n_neighbors', max=20, min=1), Output()), _dom_classes=(…
